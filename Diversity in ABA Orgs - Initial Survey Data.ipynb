# %%
# Data manipulation
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Preferences
pd.options.display.max_columns=None
pd.options.display.max_rows=None

# %%
raw_data = pd.read_excel('Div in ABA survey data 9-6-23.xlsx', sheet_name=None)

raw_data
# Out:
# {'Sheet1':      Respondent                                   Service_Settings  \
#  0             3                                                NaN
#  1             4              Clinic (outpatient);Community;School;
#  2             5                        Clinic (outpatient);School;
#  3             6                                                NaN
#  4             7                             Community;Home;School;
#  5             8                               Clinic (outpatient);
#  6             9                               Clinic (outpatient);
#  7            10                               Clinic (outpatient);
#  8            11                             Home;Community;School;
#  9            12                          Clinic (outpatient);Home;
#  10           13                         District Level Services  ;
#  11           14                          Clinic (outpatient);Home;
#  12           15                               Clinic (outpatient);
# ...
